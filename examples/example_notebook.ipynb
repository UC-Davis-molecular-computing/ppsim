# %%
from ppsim import Simulation
# %matplotlib widget

# %%
a, b, u = 'A', 'B', 'U'
approximate_majority = {
    (a,b):(u,u),
    (a,u):(a,a),
    (b,u):(b,b)
}
n = 10 ** 9
sim = Simulation({a: n // 2, b: n // 2}, approximate_majority)

# %%
sim.run()
sim.history
# Out:
# A    int64243
# B    int64
# U    int64
# dtype: object
# A    int64
# B    int64
# U    int64
# dtype: object
#                     A          B          U
# time
# 0.000000    500000000  500000000          0
# 1.000028    379929773  379912460  240157767
# 2.000045    349088338  349096783  301814879
# 3.000056    338932881  338959682  322107437
# 4.000078    335368839  335368898  329262263
# ...               ...        ...        ...
# 60.205862   999999993          0          7
# 61.380507   999999999          0          1
# 63.242838  1000000000          0          0
# 64.242838  1000000000          0          0
# 64.242838  1000000000          0          0
#
# [65 rows x 3 columns]

# %%
import pandas_alive
sim.history.plot_animated()
# Out:
# Generating BarChartRace, plotting ['A', 'B', 'U']
# C:\Users\Eric\AppData\Roaming\Python\Python37\site-packages\pandas_alive\charts.py:221: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df.columns)
# C:\Users\Eric\AppData\Roaming\Python\Python37\site-packages\pandas_alive\charts.py:222: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# BarChartRace(df=                      A            B            U
# time
# 0.000000   5.000000e+08  500000000.0          0.0
# 0.200006   4.759860e+08  475982492.0   48031553.4
# 0.400011   4.519719e+08  451964984.0   96063106.8
# 0.600017   4.279579e+08  427947476.0  144094660.2
# 0.800022   4.039438e+08  403929968.0  192126213.6
# ...                 ...          ...          ...
# 64.242838  1.000000e+09          0.0          0.0
# 64.242838  1.000000e+09          0.0          0.0
# 64.242838  1.000000e+09          0.0          0.0
# 64.242838  1.000000e+09          0.0          0.0
# 64.242838  1.000000e+09          0.0          0.0
#
# [321 rows x 3 columns], interpolate_period=True, steps_per_period=5, period_length=500, period_fmt='%d/%m/%Y', figsize=array([6.5, 3.5]), title=None, fig=<Figure size 936x504 with 1 Axes>, cmap='dark24', tick_label_size=7, period_label=True, period_summary_func=None, fixed_max=False, dpi=144, writer=None, enable_progress_bar=False, kwargs={}, orientation='h', sort='desc', label_bars=True, bar_label_size=7, n_visible=3, fixed_order=False, perpendicular_bar_func=None)

# %%
import pandas as pd
hist = pd.DataFrame(data= sim.configs, index=sim.times)
hist
# Out:
#                    0           1          2
# 0.000000   500000000   500000000          0
# 1.000039   379929585   379932128  240138287
# 2.000067   349082858   349105372  301811770
# 3.000067   338935732   338976044  322088224
# 4.000085   335345423   335403754  329250823
# 5.000104   334059503   334117220  331823277
# 6.000124   333560482   333650353  332789165
# 7.000143   333341669   333481131  333177200
# 8.000176   333250520   333450224  333299256
# 9.000206   333200459   333467395  333332146
# 10.000234  333131334   333522760  333345906
# 11.000246  333080583   333595614  333323803
# 12.000265  332976348   333695057  333328595
# 13.000287  332834991   333805100  333359909
# 14.000290  332633992   334033717  333332291
# 15.000317  332345401   334346145  333308454
# 16.000340  331952492   334747366  333300142
# 17.000349  331379207   335310219  333310574
# 18.000373  330585030   336058384  333356586
# 19.000382  329521128   337158607  333320265
# 20.000401  328021947   338673990  333304063
# 21.000420  325937573   340792789  333269638
# 22.000438  323043145   343796701  333160154
# 23.000446  318998853   347952256  333048891
# 24.000451  313388031   353781061  332830908
# 25.000452  305649952   361998776  332351272
# 26.000456  294982814   373544736  331472450
# 27.000463  280444666   389810563  329744771
# 28.000480  260897483   412723452  326379065
# 29.000482  235046922   444860931  320092147
# 30.000493  202075088   489527632  308397280
# 31.000504  162274645   549919605  287805750
# 32.000520  118420548   627371934  254207518
# 33.000545   76238179   717623686  206138135
# 34.000562   42427547   808661587  148910866
# 35.000581   20487647   885172395   94339958
# 36.000587    8835350   938336340   52828310
# 37.000601    3531123   969647188   26821689
# 38.000605    1353067   985965753   12681180
# 39.000619     505918   993786637    5707445
# 40.000621     187722   997330728    2481550
# 41.000651      69355   998878081    1052564
# 42.000675      25437   999535569     438994
# 43.000696       9223   999809949     180828
# 44.000729       3469   999923346      73185
# 45.000784       1330   999969413      29257
# 46.000841        501   999987758      11741
# 47.001080        193   999995214       4593
# 48.001085         74   999998056       1870
# 49.001577         26   999999241        733
# 50.002463         10   999999696        294
# 51.005101          5   999999888        107
# 52.005686          2   999999956         42
# 53.027031          1   999999981         18
# 54.174460          0   999999993          7
# 55.746778          0   999999999          1
# 56.746778          0  1000000000          0
# 56.746778          0  1000000000          0

# %%
hist.dtypes
# Out:
# 0    int64
# 1    int64
# 2    int64
# dtype: object

# %%
import pandas_alive

covid_df = pandas_alive.load_dataset()

animated_line_chart = covid_df.diff().fillna(0).plot_animated(kind='line',period_label=False,add_legend=False)

animated_bar_chart = covid_df.plot_animated(n_visible=10)

pandas_alive.animate_multiple_plots('examples/example-bar-and-line-chart.gif',[animated_bar_chart,animated_line_chart],
    enable_progress_bar=True)

# %%
import pandas_alive
from IPython.display import HTML

animated_html = sim.history.plot_animated().get_html5_video()

HTML(animated_html)
# Out:
# Generating BarChartRace, plotting ['A', 'B', 'U']
# C:\Users\Eric\AppData\Roaming\Python\Python37\site-packages\pandas_alive\charts.py:221: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df.columns)
# C:\Users\Eric\AppData\Roaming\Python\Python37\site-packages\pandas_alive\charts.py:222: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="936" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
from ppsim import StatePlotter
sp = StatePlotter()
sim.add_snapshot(sp)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sim.run()
sim.snapshot_slider()
# Out:
# interactive(children=(IntSlider(value=0, description='index', layout=Layout(width='100%'), max=60), Output()),…

# %%
sim.run(1, 0.1)
sim.history
# Out:
#  Time: 11.000
#                    A          B          U
# time
# 0.000000   500000000  500000000          0
# 1.000010   379927222  379906395  240166383
# 2.000010   349098811  349065460  301835729
# 3.000036   338995533  338948434  322056033
# 4.000069   335417565  335369545  329212890
# 5.000078   334132148  334053310  331814542
# 6.000102   333658269  333556029  332785702
# 7.000117   333518625  333353906  333127469
# 8.000119   333482691  333265012  333252297
# 9.000127   333498911  333180338  333320751
# 10.000162  333552492  333126893  333320615
# 10.100174  333563340  333122712  333313948
# 10.200203  333569791  333107639  333322570
# 10.300204  333571462  333101374  333327164
# 10.400223  333584257  333096940  333318803
# 10.500229  333582362  333082218  333335420
# 10.600254  333587053  333072277  333340670
# 10.700263  333597240  333058472  333344288
# 10.800276  333595896  333049905  333354199
# 10.900299  333607755  333051244  333341001
# 11.000333  333616431  333041246  333342323

# %%
sim.history.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:xlabel='time'>

# %%
sim.run()

# %%
sim.run()

# %%
approximate_majority_variant = {
    (a, b): (a, u),
    (b, a): (b, u),
    (a, u): (a, a),
    (b, u): (b, b)
}
# Simulation({a: n //2, b: n // 2}, approximate_majority_variant).print_reactions()
Simulation({a: n //2, b: n // 2}, approximate_majority_variant, transition_order='symmetric_enforced').print_reactions()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-57209a461cfc> in <module>
#       6 }
#       7 # Simulation({a: n //2, b: n // 2}, approximate_majority_variant).print_reactions()
# ----> 8 Simulation({a: n //2, b: n // 2}, approximate_majority_variant, transition_order='symmetric_enforced').print_reactions()
#
# ~\PycharmProjects\ppsim\ppsim\ppsim.py in __init__(self, init_config, rule, simulator_method, transition_order, **kwargs)
#     258                             raise ValueError(f'''Asymmetric interaction:
#     259                                             {a, b} -> {self.rule(a,b,**kwargs)}
# --> 260                                             {b, a} -> {self.rule(b, a,**kwargs)}''')
#     261
#     262         if simulator_method.lower() == 'multibatch':
#
# ValueError: Asymmetric interaction:
#                                             ('A', 'B') -> ('A', 'U')
#                                             ('B', 'A') -> ('B', 'U')

# %%
sim

# %%
from ppsim import time_trials
import numpy as np

ns = [int(n) for n in np.geomspace(10, 10 ** 8, 20)]
def initial_condition(n):
    return {'A': n // 2, 'B': n // 2}
df = time_trials(approximate_majority, ns, initial_condition, num_trials=100, max_wallclock_time = 30)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
df
# Out:
#               n       time
# 0            10   7.000000
# 1            10   7.400000
# 2            10   5.400000
# 3            10  15.100000
# 4            10   5.900000
# ...         ...        ...
# 1524  100000000  50.273655
# 1525  100000000  50.440260
# 1526  100000000  56.497314
# 1527  100000000  51.880454
# 1528  100000000  50.548712
#
# [1529 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib as plt
a = sns.lineplot(x='n', y='time', data=df)
a.set_xscale('log')
# plt.xscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a292370cf9e0> in <module>
#       1 import seaborn as sns
#       2 import matplotlib as plt
# ----> 3 a = sns.lineplot(x='n', y='time', data=df)
#       4 a.set_xscale('log')
#       5 # plt.xscale('log')
#
# NameError: name 'df' is not defined

# %%
from math import ceil, floor

def discrete_averaging(a, b):
    avg = (a + b) / 2
    return floor(avg), ceil(avg)

n = 10 ** 8
sim = Simulation({0: n // 2, 100: n // 2}, discrete_averaging)

# %%
sp = StatePlotter()
sim.add_snapshot(sp)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sp.ax.tick_params(axis='x', labelsize=5)

# %%
sp.ax.set_yscale('linear')

# %%
sim.run(20, 0.1)
sim.snapshot_slider()
# Out:
# interactive(children=(IntSlider(value=0, description='index', layout=Layout(width='100%'), max=200), Output())…

# %%
sp.ax.set_yscale('symlog')

# %%
sim.snapshots[0].ax.set_yscale('symlog')

# %%
sim.run()

# %%
sim.history
# Out:
#                       0       1        2        3        4        5         6  \
# time
# 0.000000e+00  500000000       0        0        0        0        0         0
# 1.000067e+00  119270875  823520  1166625  5446071  2497691  2665469  17312945
# 2.001296e+00   17976311  334331   551387  1900610  1416207  1876790   5849469
# 3.002960e+00    2464698   52675    91010   303162   254998   366882   1014449
# 4.005906e+00     332228    7320    12534    41964    35754    52923    145019
# ...                 ...     ...      ...      ...      ...      ...       ...
# 5.347354e+07          0       0        0        0        0        0         0
# 5.358760e+07          0       0        0        0        0        0         0
# 7.028421e+07          0       0        0        0        0        0         0
# 7.733692e+07          0       0        0        0        0        0         0
# 7.733692e+07          0       0        0        0        0        0         0
#
#                     7        8        9  ...       41       42       43  \
# time                                     ...
# 0.000000e+00        0        0        0  ...        0        0        0
# 1.000067e+00  8181000  5074008  9605471  ...  9606911  5072745  8184406
# 2.001296e+00  4419008  4728875  7078539  ...  7084169  4728981  4418572
# 3.002960e+00   918876  1150811  1800103  ...  1799786  1153656   917635
# 4.005906e+00   137969   182867   300720  ...   301860   183338   137560
# ...               ...      ...      ...  ...      ...      ...      ...
# 5.347354e+07        0        0        0  ...        0        0        0
# 5.358760e+07        0        0        0  ...        0        0        0
# 7.028421e+07        0        0        0  ...        0        0        0
# 7.733692e+07        0        0        0  ...        0        0        0
# 7.733692e+07        0        0        0  ...        0        0        0
#
#                     44       45       46       47       48      49         50
# time
# 0.000000e+00         0        0        0        0        0       0  500000000
# 1.000067e+00  17303573  2658181  2493866  5446067  1168722  823979  119275925
# 2.001296e+00   5846420  1875601  1416376  1903665   551621  333487   17978124
# 3.002960e+00   1014660   365621   254239   301862    91255   52671    2462578
# 4.005906e+00    143933    52961    35938    41344    12828    7167     331215
# ...                ...      ...      ...      ...      ...     ...        ...
# 5.347354e+07         0        0        0        0        0       0          0
# 5.358760e+07         0        0        0        0        0       0          0
# 7.028421e+07         0        0        0        0        0       0          0
# 7.733692e+07         0        0        0        0        0       0          0
# 7.733692e+07         0        0        0        0        0       0          0
#
# [35006 rows x 51 columns]

# %%
def self_stabilizing_clock(a, b, m, p=1):
    # states a, b in (0, ..., m-1, 'N')
    if a in range(m) and b in range(m):
        # drip reaction
        if a == b:
            return {((a + 1) % m, b): p}
        # epidemic reaction
        elif (a + 1) % m == b:
            return b, b
        elif (b + 1) % m == a:
            return a, a
        # clipping reaction
        else:
            return 'N', 'N'
    # recovery epidemic reactions
    elif a == 'N':
        return b, b
    elif b == 'N':
        return a, a
    
m = 12
n = 10 ** 9
sim = Simulation({i: n // m for i in range(m)}, self_stabilizing_clock, m=m)
sim.add_snapshot(StatePlotter())
sim.add_snapshot(HistoryPlotter())
